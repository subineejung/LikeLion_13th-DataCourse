# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Subin Jung\\Documents\\GitHub\\LikeLion_13th-DataCourse\\pp_01'

# %%
import time
# url = 'https://www.coupang.com/'
url = 'https://www.coupang.com/np/search?component=&q=%EC%B6%94%EC%84%9D%EC%84%A0%EB%AC%BC&channel=user'
driver = webdriver.Chrome('./chromedriver')
driver.get(url)

# %%
## 검색 : //*[@id="headerSearchKeyword"]
## 버튼 : //*[@id="headerSearchBtn"]

# %%
sel_search = driver.find_element_by_xpath('//*[@id="headerSearchKeyword"]')
sel_btn = driver.find_element_by_xpath('//*[@id="headerSearchBtn"]')

# %%
page = driver.page_source
soup = BeautifulSoup(page, 'lxml')
soup.title
# Out:
# <title>쿠팡! - 추석선물</title>

# %%
prod_all = soup.find_all('div', class_="name")
prod_list = []
for one in prod_all:
    if len(one.text):
        prod_list.append(one.text)
        print(one.text)
# Out:
# 맥심 카누 8-1호 커피세트, 1세트, 카누 마일드 로스트 아메리카노 9g x 5p + 카누 다크 로스트 아메리카노 9g x 2p + 카누 디카페인 아메리카노 9g + 오름머그 2p
# 종근당 침향환 골드, 3.75g, 60개입
# 너트리 견과류 선물세트 순백1호, 1세트, 800g
# 담미정 꽃한과 세트, 284g, 1세트
# 대웅제약 에너씨슬 밀크씨슬 간영양제, 30개입, 1개
# 조은장어즙[Haccp 인증] 기력회복 1등공신 110ml x 30포 국내산 민물장어진액 건강즙 선물세트!
# 머거본 프리미엄 3호 육포 + 견과 선물세트, 635g, 1세트
# 풍년보감 고려홍삼정 6년근 밸런스타임, 10g, 100개입
# 동의 침향원 침향환 침향 공력환 침향단 기력환 침향력 황실 황제 기력없을때 천년 추석선물, 30환
# 담미정한과 한과세트나비, 764g, 1세트
# [최고당도] 제주 황금향 로얄과 사이즈 13brix 상위1%당도 3kg / 5kg / 10kg, 가정용 3kg (중과/15~18과)
# 정관장 홍삼정 기프트세트 110gX3병
# 정원삼 6년근 고려홍삼정 365 스틱 30포 + 쇼핑백, 300g, 1세트
# 장흥표고버섯 프리미엄 표고버섯 혼합세트, 1세트, 동고 120g + 슬라이스 100g + 표고분 100g x 2p + 보자기
# 복음자리 대상 잼 선물세트 8호, 1세트
# 천지인 녹용산삼배양근, 75ml, 10병
# 고려홍삼중앙회 6년근 고려홍삼정 투데이 골드 스틱 + 쇼핑백, 10ml, 100포
# 감칠맛 상주왕곶감세트 2호 18과 (냉동), 1.1kg, 1세트
# 오설록 블루밍 티 선물 세트, 티백 9종 x 5p + 쇼핑백, 1세트
# 청정원 행복 고급호 선물세트, 1세트
# 제주 오가닉스 유기농 새싹보리 분말 선물세트, 100g*2개+전용보틀+전용스푼, 1박스
# 농협 명품 흑염소진액 국내 자연방목으로 키운 흑염소 국내산 한약재 부모님 설 추석 명절 선물세트, 70ml x 30포 (1박스)
# ...

# %% [markdown]
# ### 2페이지 클릭 한 후, 상품 가져오기

# %%
# 2페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[2]
# 3페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[3]
# 9페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[9]

# %%
## 1페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[1]
# 품목1 : //*[@id="5965004934"]/a/dl/dd/div/div[2]
# 품목2 : //*[@id="2212457094"]/a/dl/dd/div/div[2]
# 품목3 : //*[@id="4036698"]/a/dl/dd/div/div[2]
# 품목4 : //*[@id="2128872557"]/a/dl/dd/div/div[2]
# 

## 2페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[2]
## 3페이지 : //*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[3]

# %%
page = driver.page_source
soup = BeautifulSoup(page, 'lxml')
soup.title
# Out:
# <title>쿠팡! - 추석선물</title>

# %%
soup.find("div", class_='descriptions-inner').find("div", class_='name')
# Out:
# <div class="name">맥심 카누 8-1호 커피세트, 1세트, 카누 마일드 로스트 아메리카노 9g x 5p + 카누 다크 로스트 아메리카노 9g x 2p + 카누 디카페인 아메리카노 9g + 오름머그 2p</div>

# %%
all_pro = soup.find_all("div", class_='descriptions-inner')
len(all_pro)
# Out:
# 36

# %%
all_pro = soup.find_all("div", class_='descriptions-inner')

for one in all_pro:
    print(one.find("div", class_='name').text)
# Out:
# 맥심 카누 8-1호 커피세트, 1세트, 카누 마일드 로스트 아메리카노 9g x 5p + 카누 다크 로스트 아메리카노 9g x 2p + 카누 디카페인 아메리카노 9g + 오름머그 2p
# 종근당 침향환 골드, 3.75g, 60개입
# 너트리 견과류 선물세트 순백1호, 1세트, 800g
# 담미정 꽃한과 세트, 284g, 1세트
# 대웅제약 에너씨슬 밀크씨슬 간영양제, 30개입, 1개
# 조은장어즙[Haccp 인증] 기력회복 1등공신 110ml x 30포 국내산 민물장어진액 건강즙 선물세트!
# 머거본 프리미엄 3호 육포 + 견과 선물세트, 635g, 1세트
# 풍년보감 고려홍삼정 6년근 밸런스타임, 10g, 100개입
# 동의 침향원 침향환 침향 공력환 침향단 기력환 침향력 황실 황제 기력없을때 천년 추석선물, 30환
# 담미정한과 한과세트나비, 764g, 1세트
# [최고당도] 제주 황금향 로얄과 사이즈 13brix 상위1%당도 3kg / 5kg / 10kg, 가정용 3kg (중과/15~18과)
# 정관장 홍삼정 기프트세트 110gX3병
# 정원삼 6년근 고려홍삼정 365 스틱 30포 + 쇼핑백, 300g, 1세트
# 장흥표고버섯 프리미엄 표고버섯 혼합세트, 1세트, 동고 120g + 슬라이스 100g + 표고분 100g x 2p + 보자기
# 복음자리 대상 잼 선물세트 8호, 1세트
# 천지인 녹용산삼배양근, 75ml, 10병
# 고려홍삼중앙회 6년근 고려홍삼정 투데이 골드 스틱 + 쇼핑백, 10ml, 100포
# 감칠맛 상주왕곶감세트 2호 18과 (냉동), 1.1kg, 1세트
# 오설록 블루밍 티 선물 세트, 티백 9종 x 5p + 쇼핑백, 1세트
# 청정원 행복 고급호 선물세트, 1세트
# 제주 오가닉스 유기농 새싹보리 분말 선물세트, 100g*2개+전용보틀+전용스푼, 1박스
# 농협 명품 흑염소진액 국내 자연방목으로 키운 흑염소 국내산 한약재 부모님 설 추석 명절 선물세트, 70ml x 30포 (1박스)
# ...

# %%
page_start = 1
page_end = 10
for page in range(page_start, page_end+1, 1):

    # 각각 페이지의 소스를 가져오기
    page = driver.page_source
    soup = BeautifulSoup(page, 'lxml')
    all_pro = soup.find_all("div", class_='descriptions-inner')
    
    prod = []
    for one in prod:
        print(one.find("div", class_='name').text)   
    print(prod)
    
    if page != 1:
        xpath_url = '//*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[' + str(page)+ ']'
        sel_ele = driver.find_element_by_xpath(xpath_url)
        sel_ele.click()
        time.sleep(3)
# Out:
# []
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-11-5755a9d33dc3> in <module>
#      15     if page != 1:
#      16         xpath_url = '//*[@id="searchOptionForm"]/div[2]/div[2]/div[5]/span[2]/a[' + str(page)+ ']'
# ---> 17         sel_ele = driver.find_element_by_xpath(xpath_url)
#      18         sel_ele.click()
#      19         time.sleep(3)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
# ...
